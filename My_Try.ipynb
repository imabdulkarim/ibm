# %%
str = 'hello world from A.F'
print(str)
# Out:
# hello world from A.F

# %% [markdown]
# ## MarkDown

# %% [markdown]
# # Now will copute some opperations

# %%
tax = (20 + 5 ) * 4
print("the tax equal : " , tax )
# Out:
# the tax equal :  100
